# %%
from taipan_analysis import *
data_dir = r"Z:\cycle\current\data\sics"

# %%
np.arange?

# %%
data_dir = r"Z:\cycle\current\data\sics"

#rsm1 = TaipanRSM(data_dir, file_range=(92339,92360))
#rsm2 = TaipanRSM(data_dir, file_range=(92384, 92402))
#rsm3 = TaipanRSM(data_dir, file_range=(92439, 92456))

# %%
#l = np.arange(390, 700, 10)
# %matplotlib notebook

rsm2.sort_by("qh")
fig, ax = rsm2.plot(axis_1="ql", axis_2="qh", levels=50, log=False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#l = np.arange(390, 700, 10)
# %matplotlib notebook

rsm3.sort_by("qh")
fig, ax = rsm3.plot(axis_1="ql", axis_2="qh", levels=50, log=False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#ax.scatter(a.cat.qh, -a.cat.ql)
#scans = [TaipanNexus(os.path.join(data_dir, f"TPN0092{i}.nx.hdf")) for i in range(405,410)]

for i in range(405,414):
    scan = TaipanNexus(os.path.join(data_dir, f"TPN0092{i}.nx.hdf"))
    ax.scatter(-scan.cat.ql, scan.cat.qh, label=f"{scan.cat.filename}")
    ax.legend()

# %%
#rsm4 = TaipanRSM(data_dir, file_range=(92467, 92495))
from taipan_analysis import *
data_dir = r"Z:\cycle\current\data\sics"
rsm5 = TaipanRSM(data_dir, file_range=(92514, 92540))

# %matplotlib notebook

rsm5.sort_by("qh")
fig, ax = rsm5.plot(axis_1="ql", axis_2="qh", levels=20, log=False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
rsm5.line_profile(axis_1="ql", axis_2="qh", width=0.005)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
type(rsm5.line_slice)
# Out:
# NoneType

# %%
# %matplotlib notebook
a = TaipanNexus(os.path.join(data_dir, "TPN0092506.nx.hdf"))
a.plot("som")
# Out:
# <img src="data:image/png;base64,..." width="432">
# (<Figure size 432x288 with 1 Axes>,
#  <AxesSubplot:xlabel='som', ylabel='Counts/sec'>)

# %%
str(spp.cat.title)[3:-2]
# Out:
# 'magnetic peak ++ channel 1'

# %%
a = TaipanNexus(os.path.join(data_dir, "TPN0092561.nx.hdf"))
fig, ax = plt.subplots()

ax.errorbar(a.cat.s1, a.cts, a.cts_err, fmt="o-", label=f"qh = {a.cat.qh[0]:.5f}")
#ax.errorbar(b.cat.qh, b.cts, b.cts_err, fmt="o-", label=f"ql = {b.cat.ql[0]:.5f}")
ax.legend()
#ax.set_title(f"ql = {a.cat.ql[0]:.5f}, qk = {a.cat.qk[0]:.5f}")
#a.plot(axis="ql")

# %%
a.scan_axis
# Out:
# ['ql', 's1']

# %%
from taipan_analysis import *
data_dir = r"Z:\cycle\current\data\sics"

pscans = PolarisedTAIPAN(directory=data_dir, file_range=(92561, 92700))

# %%
# %matplotlib notebook
fig, ax = plt.subplots(2,2)

x, y, yerr = pscans.average_datasets(SpinChannel.UP_UP)
ax[0,0].errorbar(x, y, np.sqrt(y), fmt="o-")
ax[0,0].set_title("++")

x, y, yerr = pscans.average_datasets(SpinChannel.UP_DOWN)
ax[0,1].errorbar(x, y, np.sqrt(y), fmt="o-")
ax[0,1].set_title("+-")

x, y, yerr = pscans.average_datasets(SpinChannel.DOWN_UP)
ax[1,0].errorbar(x, y, np.sqrt(y), fmt="o-")
ax[1,0].set_title("-+")

x, y, yerr = pscans.average_datasets(SpinChannel.DOWN_DOWN)
ax[1,1].errorbar(x, y, np.sqrt(y), fmt="o-")
ax[1,1].set_title("--")

#sc = [spp, spm, smp, smm]
for idx, a in enumerate(ax.flatten()):
    a.set_xlabel("ql")
    a.set_ylabel("counts/250k mon.")
    a.set_ylim(10, 40)
    #a.set_title(f"{sc[idx].cat.title}")
# Out:
# <img src="data:image/png;base64,..." width="727.2727115095158">

# %%
fig, ax = plt.subplots()

x, y, yerr = pscans.average_datasets(SpinChannel.UP_DOWN)
ax.errorbar(x, y, np.sqrt(y), fmt="o-")
x, y, yerr = pscans.average_datasets(SpinChannel.DOWN_UP)
ax.errorbar(x, y, np.sqrt(y), fmt="o-")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <ErrorbarContainer object of 3 artists>

# %%
fig, ax = plt.subplots()

for scan in pscans.nuclear_scans["UP_UP"]:
    ax.errorbar(scan.cat.s1, scan.cts, scan.cts_err)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
pscans.nuclear_scans["UP_UP"][-1].cat.filename
# Out:
# 'TPN0092599.nx.hdf'

# %%
a = TaipanNexus(os.path.join(data_dir, "TPN0092859.nx.hdf"))
# Out:
# array([37.  , 35.5 , 35.  , 38.  , 39.75, 39.25, 38.5 ])

# %%
from taipan_analysis import *
data_dir = r"Z:\cycle\current\data\sics"

#pz_scans = PolarisedTAIPAN(directory=data_dir, file_range=(92859, 92899))
pxy_scans = PolarisedTAIPAN(directory=data_dir, file_range=(93244, 93410))

# %%
fig, ax = plt.subplots()

x, y, yerr = pxy_scans.average_datasets(SpinChannel.UP_DOWN)
ax.errorbar(x, y, np.sqrt(y), fmt="o-", label=SpinChannel.UP_DOWN.value)
x, y, yerr = pxy_scans.average_datasets(SpinChannel.DOWN_UP)
ax.errorbar(x, y, np.sqrt(y), fmt="o-", label=SpinChannel.DOWN_UP.value)
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# %matplotlib notebook
fig, ax = plt.subplots(2,2)

x, y, yerr = pz_scans.average_datasets(SpinChannel.UP_UP)
ax[0,0].errorbar(x, y, np.sqrt(y), fmt="o-")
ax[0,0].set_title("++")

x, y, yerr = pz_scans.average_datasets(SpinChannel.UP_DOWN)
ax[0,1].errorbar(x, y, np.sqrt(y), fmt="o-")
ax[0,1].set_title("+-")

x, y, yerr = pz_scans.average_datasets(SpinChannel.DOWN_UP)
ax[1,0].errorbar(x, y, np.sqrt(y), fmt="o-")
ax[1,0].set_title("-+")

x, y, yerr = pz_scans.average_datasets(SpinChannel.DOWN_DOWN)
ax[1,1].errorbar(x, y, np.sqrt(y), fmt="o-")
ax[1,1].set_title("--")

#sc = [spp, spm, smp, smm]
for idx, a in enumerate(ax.flatten()):
    a.set_xlabel("ql")
    a.set_ylabel("counts/250k mon.")
    a.set_ylim(20, 60)
    #a.set_title(f"{sc[idx].cat.title}")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
pxy_scans = PolarisedTAIPAN(directory=data_dir, file_range=(92899, 92980))



# %matplotlib notebook
fig, ax = plt.subplots(2,2)

x, y, yerr = pxy_scans.average_datasets(SpinChannel.UP_UP)
ax[0,0].errorbar(x, y, np.sqrt(y), fmt="o-")
ax[0,0].set_title("++")

x, y, yerr = pxy_scans.average_datasets(SpinChannel.UP_DOWN)
ax[0,1].errorbar(x, y, np.sqrt(y), fmt="o-")
ax[0,1].set_title("+-")

x, y, yerr = pxy_scans.average_datasets(SpinChannel.DOWN_UP)
ax[1,0].errorbar(x, y, np.sqrt(y), fmt="o-")
ax[1,0].set_title("-+")

x, y, yerr = pxy_scans.average_datasets(SpinChannel.DOWN_DOWN)
ax[1,1].errorbar(x, y, np.sqrt(y), fmt="o-")
ax[1,1].set_title("--")

#sc = [spp, spm, smp, smm]
for idx, a in enumerate(ax.flatten()):
    a.set_xlabel("ql")
    a.set_ylabel("counts/250k mon.")
    a.set_ylim(20, 40)
    #a.set_title(f"{sc[idx].cat.title}")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
fig, ax = plt.subplots()

x, y, yerr = pxy_scans.average_datasets(SpinChannel.UP_DOWN)
ax.errorbar(x, y, np.sqrt(y), fmt="o-", label=SpinChannel.UP_DOWN.value)
x, y, yerr = pxy_scans.average_datasets(SpinChannel.DOWN_UP)
ax.errorbar(x, y, np.sqrt(y), fmt="o-", label=SpinChannel.DOWN_UP.value)
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="703.6363483854565">

# %%
from scipy.optimize import curve_fit
import seaborn as sns

fig, ax = plt.subplots()
col = sns.color_palette("tab10")

for idx, scan in enumerate(pz_scans.nuclear_scans["UP_UP"]):
    ax.plot(scan.cat.s1, scan.cts, color=col[idx])
    amp = 1000
    x0 = -8.8
    std = 0.5
    bg = 10
    x = np.linspace(scan.cat.s1[0], scan.cat.s1[-1], num=50)
    popt, pcov = curve_fit(
        gaussian, 
        scan.cat.s1, 
        scan.cts, 
        p0=[amp, x0, std, bg], 
        bounds=([500, -8.7, 0.2, 0], [7000, -8.9, 2, 500]), 
        maxfev=10000
    )
    print(popt)
    ax.plot(x, gaussian(x,  *popt), ".", color=col[idx])
    
for idx, scan in enumerate(pz_scans.nuclear_scans["UP_DOWN"]):
    ax.plot(scan.cat.s1, scan.cts, ".", color=col[idx+2])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
curve_fit?

# %%
fig, ax = plt.subplots(1,2)

x, y, yerr = pz_scans.average_datasets(SpinChannel.UP_DOWN)
ax[0].errorbar(x, y, np.sqrt(y), fmt="o-", label=SpinChannel.UP_DOWN.value)
x, y, yerr = pz_scans.average_datasets(SpinChannel.DOWN_UP)
ax[0].errorbar(x, y, np.sqrt(y), fmt="o-", label=SpinChannel.DOWN_UP.value)
ax[0].legend()

x, y, yerr = pxy_scans.average_datasets(SpinChannel.UP_DOWN)
ax[1].errorbar(x, y, np.sqrt(y), fmt="o-", label=SpinChannel.UP_DOWN.value)
x, y, yerr = pxy_scans.average_datasets(SpinChannel.DOWN_UP)
ax[1].errorbar(x, y, np.sqrt(y), fmt="o-", label=SpinChannel.DOWN_UP.value)
ax[1].legend()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
a = TaipanNexus(os.path.join(data_dir, "TPN0092520.nx.hdf"))
b = TaipanNexus(os.path.join(data_dir, "TPN0093049.nx.hdf"))

# %%
fig, ax = a.plot()

b.plot(fig=fig, ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:xlabel='ql', ylabel='Counts/sec'>)

# %%
scans = PolarisedTAIPAN(directory=data_dir, file_range=(92856, 92901))

# %%
scans.nuclear_scans
# Out:
# {'UP_UP': [<taipan_analysis.TaipanNexus at 0x26a11716d30>,
# ...
#  'UP_DOWN': [<taipan_analysis.TaipanNexus at 0x26a14f1ab80>,
# ...
#  'DOWN_UP': [<taipan_analysis.TaipanNexus at 0x26a15113dc0>],
#  'DOWN_DOWN': [<taipan_analysis.TaipanNexus at 0x26a151ead90>]}

# %%
# %matplotlib notebook
fig, ax = plt.subplots()

ax.plot(scans.nuclear_scans["UP_UP"][0].cat.s1, scans.nuclear_scans["UP_UP"][0].cts, "o-", label="xy-dir")
ax.plot(scans.nuclear_scans["UP_DOWN"][0].cat.s1, scans.nuclear_scans["UP_DOWN"][0].cts, "o-", label="xy-dir")

ax.plot(scans.nuclear_scans["UP_UP"][1].cat.s1, scans.nuclear_scans["UP_UP"][1].cts, "o-", label="z-dir")
ax.plot(scans.nuclear_scans["UP_DOWN"][1].cat.s1, scans.nuclear_scans["UP_DOWN"][1].cts, "o-", label="z-dir")

#ax.plot(scans.nuclear_scans["DOWN_DOWN"][0].cat.s1, scans.nuclear_scans["DOWN_DOWN"][0].cts, "o-", label="--")
#ax.plot(scans.nuclear_scans["UP_DOWN"][1].cat.s1, scans.nuclear_scans["UP_DOWN"][1].cts, "o-", label="xy-dir")

ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
scans.nuclear_scans["UP_UP"][0].cat.start_time
# Out:
# array([b'2022-06-24 17:56:44'], dtype='|S20')

# %%
scans.nuclear_scans["UP_UP"][0].cat.end_time[0]

date, time = scans.nuclear_scans["UP_UP"][0].cat.end_time[0].decode("utf-8").split(' ')
#date = scans.nuclear_scans["UP_UP"][0].cat.end_time[0].decode("utf-8").split(' ')[0]

print(date)
year, month, day = date.split('-')
hour, minute, second = time.split(':')
datetime.datetime(int(year), int(month), int(day), int(hour), int(minute), int(second))
# Out:
# 2022-06-24

# %%
import datetime
# Out:
# datetime.datetime(2022, 6, 24, 18, 1, 2)

# %%
datetime.datetime?

# %%
datetime.datetime(scans.nuclear_scans["UP_UP"][0].cat.end_time[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4824/2295739872.py in <module>
# ----> 1 datetime.datetime(scans.nuclear_scans["UP_UP"][0].cat.end_time[0])
#
# TypeError: an integer is required (got type numpy.bytes_)

# %% [markdown]
# # Cell lifetime analysis

# %%
pz_scans.nuclear_scans
# Out:
# {'UP_UP': [<taipan_analysis.TaipanNexus at 0x1ead97aac40>,
# ...
#  'UP_DOWN': [<taipan_analysis.TaipanNexus at 0x1ead7e3fe20>,
# ...
#  'DOWN_UP': [],
#  'DOWN_DOWN': [<taipan_analysis.TaipanNexus at 0x1ead97122b0>]}
