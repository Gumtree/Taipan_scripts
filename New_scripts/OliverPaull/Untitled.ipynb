# %%
from taipan_analysis import *

# %%
data_dir = r"Z:\cycle\current\data\sics"

rsm = TaipanRSM(data_dir, file_range=(94800, 94824))
#rsm.sort_by("filename")
#fig, ax = rsm2.plot(axis_1="ql", axis_2="qh", levels=50, log=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Gumtree\git\Taipan_scripts\New_scripts\OliverPaull\taipan_analysis.py in _load_files(self)
#     527             try:
# --> 528                 self.data["qh"][idx, :] = scan.cat.qh[:]
#     529                 self.data["qk"][idx, :] = scan.cat.qk[:]
#
# ValueError: could not broadcast input array from shape (26,) into shape (16,)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13308/3093803207.py in <module>
#       1 data_dir = r"Z:\cycle\current\data\sics"
#       2
# ----> 3 rsm = TaipanRSM(data_dir, file_range=(94800, 94824))
#       4 #rsm.sort_by("filename")
#       5 #fig, ax = rsm2.plot(axis_1="ql", axis_2="qh", levels=50, log=False)
#
# ...

# %%
rsm.scans

# %%
rsm.sort_by("filename")

# %%
rsm.scans

# %%
# %matplotlib notebook
rsm.plot(levels=50, vmin=30, vmax=300)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (<Figure size 640x480 with 2 Axes>, <AxesSubplot:xlabel='qh', ylabel='ql'>)
